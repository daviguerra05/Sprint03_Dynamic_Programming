# %% [markdown]
# # Importações

# %%
import funcoes
from Classes import Professor

# %% [markdown]
# # Insigths, análises e gráficos das tabelas

# %% [markdown]
# ## Tabela Alunos

# %%
alunos = funcoes.receber_dados_alunos()

# %% [markdown]
# ### Separado Por turmas

# %% [markdown]
# Media

# %%
alunos.media_pontuacao_turma()
# Out:
#      Turma    Pontuacao
# 0   10LPNW  1007.200000
# 1   10LPNX  1046.968504
# 2   10LPNY  1076.562044
# 3   10LPNZ   988.975207
# 4    1LPNW  1100.915385
# 5    1LPNX  1010.801802
# 6    1LPNY  1192.201550
# 7    1LPNZ  1146.079365
# 8    2LPNW  1052.700855
# 9    2LPNX  1161.327731
# 10   2LPNY  1090.870229
# 11   2LPNZ  1112.257812
# 12   3LPNW  1069.415254
# 13   3LPNX  1106.336364
# 14   3LPNY  1169.268519
# 15   3LPNZ  1032.658537
# 16   4LPNW  1035.598592
# 17   4LPNX  1061.733871
# 18   4LPNY  1193.305085
# 19   4LPNZ  1123.577236
# 20   5LPNW  1027.372414
# 21   5LPNX  1003.152542
# 22   5LPNY  1085.742424
# 23   5LPNZ  1018.252101
# 24   6LPNW  1092.721311
# 25   6LPNX  1047.000000
# 26   6LPNY  1015.082192
# 27   6LPNZ  1149.166667
# 28   7LPNW  1087.913386
# 29   7LPNX  1041.281481
# 30   7LPNY  1001.335878
# 31   7LPNZ  1130.048387
# 32   8LPNW  1075.272727
# 33   8LPNX   985.407407
# 34   8LPNY  1034.226087
# 35   8LPNZ  1036.760331
# 36   9LPNW   934.359375
# ...

# %% [markdown]
# Mediana

# %%
alunos.mediana_pontuacao_turma()
# Out:
#      Turma  Pontuacao
# 0   10LPNW      842.0
# 1   10LPNX      885.0
# 2   10LPNY      905.0
# 3   10LPNZ      707.0
# 4    1LPNW      898.0
# 5    1LPNX      797.0
# 6    1LPNY      947.0
# 7    1LPNZ      915.5
# 8    2LPNW      919.0
# 9    2LPNX      942.0
# 10   2LPNY      864.0
# 11   2LPNZ      881.0
# 12   3LPNW      849.5
# 13   3LPNX      899.0
# 14   3LPNY     1063.5
# 15   3LPNZ      825.0
# 16   4LPNW      801.0
# 17   4LPNX      909.0
# 18   4LPNY      982.0
# 19   4LPNZ      926.0
# 20   5LPNW      845.0
# 21   5LPNX      889.0
# 22   5LPNY      964.0
# 23   5LPNZ      856.0
# 24   6LPNW      967.5
# 25   6LPNX      863.0
# 26   6LPNY      806.5
# 27   6LPNZ      917.5
# 28   7LPNW      974.0
# 29   7LPNX      891.0
# 30   7LPNY      807.0
# 31   7LPNZ      888.0
# 32   8LPNW      877.0
# 33   8LPNX      856.0
# 34   8LPNY      853.0
# 35   8LPNZ      817.0
# 36   9LPNW      717.5
# 37   9LPNX      841.0
# 38   9LPNY      831.5
# 39   9LPNZ      773.0

# %% [markdown]
# ### Separado por Idade

# %% [markdown]
# Média

# %%
alunos.media_pontuacao_idade()
# Out:
#     Idade    Pontuacao
# 0      18  1060.217391
# 1      19  1076.346405
# 2      20  1128.129630
# 3      21  1073.698113
# 4      22  1096.500000
# 5      23  1066.992857
# 6      24   940.777027
# 7      25  1136.409938
# 8      26  1039.925926
# 9      27  1199.931298
# 10     28  1044.149351
# 11     29   966.300000
# 12     30  1087.987342
# 13     31  1092.051948
# 14     32  1072.060606
# 15     33  1085.282609
# 16     34  1006.164474
# 17     35  1017.068493
# 18     36  1071.581699
# 19     37  1067.688406
# 20     38  1165.351724
# 21     39  1001.926966
# 22     40  1052.509934
# 23     41  1079.510067
# 24     42   995.565789
# 25     43   973.363636
# 26     44  1029.506944
# 27     45  1116.762238
# 28     46  1071.664596
# 29     47  1104.184211
# 30     48  1011.222222
# 31     49  1143.335714
# 32     50  1069.664336

# %% [markdown]
# Mediana

# %%
alunos.mediana_pontuacao_idade()
# Out:
#     Idade  Pontuacao
# 0      18      850.0
# 1      19      863.0
# 2      20      960.5
# 3      21      861.0
# 4      22      901.0
# 5      23      827.0
# 6      24      738.5
# 7      25      918.0
# 8      26      782.0
# 9      27      898.0
# 10     28      833.5
# 11     29      809.5
# 12     30      914.5
# 13     31      913.5
# 14     32      933.0
# 15     33      884.0
# 16     34      857.0
# 17     35      781.5
# 18     36      879.0
# 19     37      906.5
# 20     38      966.0
# 21     39      894.0
# 22     40      915.0
# 23     41      891.0
# 24     42      841.5
# 25     43      880.0
# 26     44      806.5
# 27     45      946.0
# 28     46      878.0
# 29     47      866.5
# 30     48      864.0
# 31     49      954.0
# 32     50      928.0

# %% [markdown]
# ### Separado por Sexo

# %% [markdown]
# Média

# %%
alunos.media_pontuacao_sexo()
# Out:
#   Sexo    Pontuacao
# 0    F  1079.895349
# 1    M  1047.747406

# %% [markdown]
# Mediana

# %%
alunos.mediana_pontuacao_sexo()
# Out:
#   Sexo  Pontuacao
# 0    F      886.0
# 1    M      859.5

# %% [markdown]
# ### Correlação pontuação

# %%
alunos.correlacaoPontuacao()
# Out:
#                 Pontuacao  Num_simulacoes  Num_insignias
# Pontuacao        1.000000        0.570108      -0.013136
# Num_simulacoes   0.570108        1.000000      -0.002916
# Num_insignias   -0.013136       -0.002916       1.000000

# %% [markdown]
# ### Desempenho Geral

# %% [markdown]
# Média

# %%
alunos.media_geral()
# Out:
# Média pontuação dos alunos: 1063.7828

# %% [markdown]
# 10 melhores

# %%
alunos.melhores_pontuacoes()
# Out:
# As 10 maiores pontuações
#                  Nome  Idade Sexo  Turma      Rm  Pontuacao  Num_simulacoes  \
# 4936     Dylan Ingram     24    M  6LPNY  335288       3000               3
# 1900   Benjamin Frank     32    M  7LPNZ  969020       2999               3
# 3757      Donna Moore     19    F  8LPNW  194064       2997               3
# 6       Eric Alvarado     36    M  2LPNW  200476       2996               3
# 1257     Robert Green     21    M  6LPNX  535839       2994               3
# 1206  Jonathan Walton     46    M  6LPNY  417998       2990               3
# 1434  Kimberly Butler     31    F  1LPNZ  989754       2987               3
# 4918   Vincent Golden     43    M  2LPNY  511350       2986               3
# 2248        Paul Tate     33    M  7LPNW  359363       2985               3
# 2814     Pamela Doyle     50    F  7LPNY  268368       2985               3
#
#       Num_insignias
# 4936             13
# 1900              2
# 3757             11
# 6                 1
# ...

# %% [markdown]
# ### Distribuição

# %%
alunos.distribuicao_pontuacao()

# %% [markdown]
# ### Simulacoes realizadas

# %% [markdown]
# Média de simulações realizadas por turma

# %%
alunos.media_simulacoes_realizadas_por_turma()
# Out:
#      Turma  Num_simulacoes
# 0   10LPNW        1.976923
# 1   10LPNX        1.929134
# 2   10LPNY        2.007299
# 3   10LPNZ        1.950413
# 4    1LPNW        1.976923
# 5    1LPNX        1.990991
# 6    1LPNY        2.046512
# 7    1LPNZ        2.126984
# 8    2LPNW        1.974359
# 9    2LPNX        2.100840
# 10   2LPNY        2.030534
# 11   2LPNZ        2.070312
# 12   3LPNW        2.016949
# 13   3LPNX        2.009091
# 14   3LPNY        2.138889
# 15   3LPNZ        2.073171
# 16   4LPNW        2.035211
# 17   4LPNX        2.048387
# 18   4LPNY        2.025424
# 19   4LPNZ        1.991870
# 20   5LPNW        2.089655
# 21   5LPNX        1.957627
# 22   5LPNY        1.969697
# 23   5LPNZ        1.983193
# 24   6LPNW        2.049180
# 25   6LPNX        1.926829
# 26   6LPNY        1.938356
# 27   6LPNZ        2.087719
# 28   7LPNW        2.094488
# 29   7LPNX        2.074074
# 30   7LPNY        1.908397
# 31   7LPNZ        1.991935
# 32   8LPNW        2.090909
# ...

# %% [markdown]
# Pontuação média por quantidade de simulações

# %%
alunos.pontuaca_media_por_quantidade_simulacoes()
# Out:
#    Num_simulacoes    Pontuacao
# 0               1   556.493437
# 1               2  1052.828801
# 2               3  1572.540445

# %% [markdown]
# ### Insígnias

# %%
alunos.distribuicao_insignias()
# Out:
#     Num_insignias  count
# 0              13    350
# 1              11    345
# 2              14    334
# 3              12    333
# 4               5    328
# 5               1    323
# 6              10    318
# 7               4    318
# 8               9    318
# 9               3    309
# 10             15    298
# 11              6    297
# 12              2    290
# 13              7    286
# 14              8    286
# 15              0    267

# %%
alunos.pontuacao_por_numero_insignias()
# Out:
#     Num_insignias    Pontuacao
# 0               0  1009.790262
# 1               1  1128.232198
# 2               2  1083.893103
# 3               3  1041.064725
# 4               4  1067.518868
# 5               5  1136.945122
# 6               6  1085.464646
# 7               7  1098.982517
# 8               8   978.409091
# 9               9  1129.188679
# 10             10  1012.915094
# 11             11  1021.388406
# 12             12  1042.942943
# 13             13  1005.394286
# 14             14  1093.559880
# 15             15  1080.375839

# %% [markdown]
# ### Desempenho por turma

# %%
alunos.diferenca_desempenho_por_turma()
# Out:
#      Turma    Pontuacao  Num_simulacoes
# 0   10LPNW  1007.200000        1.976923
# 1   10LPNX  1046.968504        1.929134
# 2   10LPNY  1076.562044        2.007299
# 3   10LPNZ   988.975207        1.950413
# 4    1LPNW  1100.915385        1.976923
# 5    1LPNX  1010.801802        1.990991
# 6    1LPNY  1192.201550        2.046512
# 7    1LPNZ  1146.079365        2.126984
# 8    2LPNW  1052.700855        1.974359
# 9    2LPNX  1161.327731        2.100840
# 10   2LPNY  1090.870229        2.030534
# 11   2LPNZ  1112.257812        2.070312
# 12   3LPNW  1069.415254        2.016949
# 13   3LPNX  1106.336364        2.009091
# 14   3LPNY  1169.268519        2.138889
# 15   3LPNZ  1032.658537        2.073171
# 16   4LPNW  1035.598592        2.035211
# 17   4LPNX  1061.733871        2.048387
# 18   4LPNY  1193.305085        2.025424
# 19   4LPNZ  1123.577236        1.991870
# 20   5LPNW  1027.372414        2.089655
# 21   5LPNX  1003.152542        1.957627
# ...

# %% [markdown]
# ## Tabela Professores

# %%
professores = funcoes.receber_dados_professores()

# %%
professores.media_idade_sexo()
# Out:
#   Sexo      Idade
# 0    F  47.503597
# 1    M  47.142857

# %%
professores.mediana_idade_sexo()
# Out:
#   Sexo  Idade
# 0    F   48.0
# 1    M   49.0

# %%
professores.media_geral_idade()
# Out:
# Média de idade dos professores: 47.342629482071715

# %%
professores.maiores_idades()
# Out:
# As 10 maiores idades dos professores:
#                   Nome  Idade Sexo  Registro
# 12       Tiffany Allen     70    F      7936
# 56        Carla Kelley     70    F      1804
# 98            Lisa Lee     70    F      1576
# 145     Michael Carter     70    M      7431
# 168         Lori Lewis     70    F      1063
# 221  Tiffany Alexander     70    F      3023
# 225      Jessica Salas     70    F      4639
# 227          Amy Kirby     70    F      7864
# 238        Robert Mays     70    M      5067
# 36    Jennifer Fleming     69    F      2981

# %%
professores.distribuicao_idade()

# %% [markdown]
# ## Tabela Coordenadores

# %%
coordenadores = funcoes.receber_dados_coordenadores()

# %%
coordenadores.grafico_sexo_por_idade()

# %% [markdown]
# ## Tabela Turmas

# %%
turmas = funcoes.receber_dados_turmas()

# %% [markdown]
# ### Distribuição por período

# %%
turmas.distribuicao_periodo()

# %% [markdown]
# # Atualização de dados

# %% [markdown]
# ## Professor

# %% [markdown]
# ### Adicionar

# %%
professorNovo = Professor.Professor(Nome='Rogério Carlos',Idade=40,Sexo='M',Registro=8004)
professores.adicionarProfessor(professorNovo)
professores.df.tail()
# Out:
# Já existe um professor com o Registro 8004.
#                    Nome  Idade Sexo  Registro
# 246       Tanya Gilmore     33    F      9233
# 247  Alejandro Johnston     52    M      5597
# 248      Dawn Fernandez     41    F      9375
# 249        Steven James     56    M      2754
# 250      Silvio Ribeiro     40    M      8004

# %% [markdown]
# ### Modificar

# %%
professores.modificar_professor_por_registro(Registro=8004,novo_nome='Silvio Ribeiro')
# Out:
# Dados do professor com Registro 8004 modificados com sucesso.

# %% [markdown]
# ### Deletar

# %%
professores.deletar_professor_por_registro(registro=8004)
professores.df.tail()
# Out:
# Professor com Registro 8004 excluído com sucesso.
#                    Nome  Idade Sexo  Registro
# 245       Matthew David     49    M      9929
# 246       Tanya Gilmore     33    F      9233
# 247  Alejandro Johnston     52    M      5597
# 248      Dawn Fernandez     41    F      9375
# 249        Steven James     56    M      2754

# %% [markdown]
# # Aplicação de regressão para prever a pontuação de um aluno e comparar com sua pontuação real

# %% [markdown]
# # Importações

# %%
import funcoes
from Classes import Professor, Coordenador, Turma, Aluno

# %% [markdown]
# # Insigths, análises e gráficos das tabelas

# %% [markdown]
# ## Tabela Alunos

# %%
alunos = funcoes.receber_dados_alunos()

# %% [markdown]
# ### Separado Por turmas

# %% [markdown]
# Media

# %%
alunos.media_pontuacao_turma()
# Out:
#      Turma    Pontuacao
# 0   10LPNW   930.692308
# 1   10LPNX   923.543307
# 2   10LPNY   902.043796
# 3   10LPNZ   845.495868
# 4    1LPNW   946.346154
# 5    1LPNX   966.666667
# 6    1LPNY   986.666667
# 7    1LPNZ   955.833333
# 8    2LPNW   910.769231
# 9    2LPNX  1005.840336
# 10   2LPNY   841.679389
# 11   2LPNZ   964.023438
# 12   3LPNW   950.084746
# 13   3LPNX   923.318182
# 14   3LPNY   998.657407
# 15   3LPNZ  1012.235772
# 16   4LPNW   910.669014
# 17   4LPNX   953.346774
# 18   4LPNY   866.991525
# 19   4LPNZ   967.113821
# 20   5LPNW   978.586207
# 21   5LPNX  1047.288136
# 22   5LPNY   943.219697
# 23   5LPNZ   817.731092
# 24   6LPNW   917.418033
# 25   6LPNX   977.642276
# 26   6LPNY   846.438356
# 27   6LPNZ   981.798246
# 28   7LPNW  1008.031496
# 29   7LPNX   957.888889
# 30   7LPNY   867.099237
# 31   7LPNZ   893.669355
# 32   8LPNW   915.189394
# 33   8LPNX   870.185185
# 34   8LPNY   785.043478
# 35   8LPNZ   895.950413
# 36   9LPNW   794.921875
# 37   9LPNX   848.333333
# 38   9LPNY   900.039683
# 39   9LPNZ   827.235772

# %% [markdown]
# Mediana

# %%
alunos.mediana_pontuacao_turma()
# Out:
#      Turma  Pontuacao
# 0   10LPNW      740.0
# 1   10LPNX      740.0
# 2   10LPNY      740.0
# 3   10LPNZ      555.0
# 4    1LPNW      740.0
# 5    1LPNX      925.0
# 6    1LPNY      740.0
# 7    1LPNZ      740.0
# 8    2LPNW      740.0
# 9    2LPNX      925.0
# 10   2LPNY      740.0
# 11   2LPNZ      832.5
# 12   3LPNW      832.5
# 13   3LPNX      740.0
# 14   3LPNY      925.0
# 15   3LPNZ      925.0
# 16   4LPNW      740.0
# 17   4LPNX      740.0
# 18   4LPNY      740.0
# 19   4LPNZ      740.0
# 20   5LPNW      925.0
# 21   5LPNX      925.0
# 22   5LPNY      740.0
# 23   5LPNZ      555.0
# 24   6LPNW      740.0
# 25   6LPNX      740.0
# 26   6LPNY      740.0
# 27   6LPNZ      925.0
# 28   7LPNW      925.0
# 29   7LPNX      740.0
# 30   7LPNY      740.0
# 31   7LPNZ      740.0
# 32   8LPNW      740.0
# 33   8LPNX      740.0
# 34   8LPNY      555.0
# 35   8LPNZ      740.0
# 36   9LPNW      740.0
# 37   9LPNX      740.0
# 38   9LPNY      740.0
# 39   9LPNZ      740.0

# %% [markdown]
# ### Separado por Idade

# %% [markdown]
# Média

# %%
alunos.media_pontuacao_idade()
# Out:
#     Idade    Pontuacao
# 0      18   934.384058
# 1      19   946.907895
# 2      20   849.629630
# 3      21   912.201258
# 4      22   903.376623
# 5      23   932.928571
# 6      24   840.000000
# 7      25  1018.074534
# 8      26   952.407407
# 9      27   891.106870
# 10     28   880.551948
# 11     29   852.156250
# 12     30   987.056962
# 13     31   818.084416
# 14     32   886.878788
# 15     33  1037.608696
# 16     34   867.796053
# 17     35   907.260274
# 18     36   931.045752
# 19     37  1002.753623
# 20     38   872.689655
# 21     39   939.550562
# 22     40   917.649007
# 23     41   951.073826
# 24     42   915.263158
# 25     43   915.389610
# 26     44   951.979167
# 27     45   922.412587
# 28     46   925.000000
# 29     47   904.309211
# 30     48   976.388889
# 31     49   932.928571
# 32     50   910.769231

# %% [markdown]
# Mediana

# %%
alunos.mediana_pontuacao_idade()
# Out:
#     Idade  Pontuacao
# 0      18      740.0
# 1      19      740.0
# 2      20      740.0
# 3      21      740.0
# 4      22      740.0
# 5      23      740.0
# 6      24      740.0
# 7      25      925.0
# 8      26      740.0
# 9      27      740.0
# 10     28      740.0
# 11     29      740.0
# 12     30      925.0
# 13     31      740.0
# 14     32      740.0
# 15     33      925.0
# 16     34      740.0
# 17     35      740.0
# 18     36      740.0
# 19     37      832.5
# 20     38      740.0
# 21     39      740.0
# 22     40      740.0
# 23     41      740.0
# 24     42      740.0
# 25     43      740.0
# 26     44      740.0
# 27     45      740.0
# 28     46      740.0
# 29     47      740.0
# 30     48      740.0
# 31     49      832.5
# 32     50      740.0

# %% [markdown]
# ### Separado por Sexo

# %% [markdown]
# Média

# %%
alunos.media_pontuacao_sexo()
# Out:
#   Sexo   Pontuacao
# 0    F  920.697674
# 1    M  920.347305

# %% [markdown]
# Mediana

# %%
alunos.mediana_pontuacao_sexo()
# Out:
#   Sexo  Pontuacao
# 0    F      740.0
# 1    M      740.0

# %% [markdown]
# ### Correlação pontuação

# %%
alunos.correlacaoPontuacao()
# Out:
#                 Pontuacao  Num_simulacoes  Num_insignias
# Pontuacao         1.00000         0.51328        1.00000
# Num_simulacoes    0.51328         1.00000        0.51328
# Num_insignias     1.00000         0.51328        1.00000

# %% [markdown]
# ### Desempenho Geral

# %% [markdown]
# Média

# %%
alunos.media_geral()
# Out:
# Média pontuação dos alunos: 920.5221044208841

# %% [markdown]
# 10 melhores

# %%
alunos.melhores_pontuacoes()
# Out:
# As 10 maiores pontuações
#                   Nome  Idade Sexo   Turma      Rm  Pontuacao  Num_simulacoes  \
# 4         Timothy Cook     49    M   1LPNZ  233747       2775               3
# 5           Ian Mclean     18    M   1LPNW  497383       2775               3
# 139    Carl Valenzuela     47    M   2LPNX  955276       2775               3
# 179          Amy Bryan     49    F   4LPNY  336447       2775               3
# 254        Karen Walsh     42    F   1LPNZ  333485       2775               3
# 258  Stephanie Nichols     50    F   1LPNY  851911       2775               3
# 263    Timothy Pittman     42    M   4LPNZ  215816       2775               3
# 381      Jeffrey Davis     27    M   3LPNY  910617       2775               3
# 387    Courtney Thomas     30    F   1LPNW  485013       2775               3
# 420        Keith Doyle     33    M  10LPNZ  188341       2775               3
#
#      Num_insignias
# 4               15
# 5               15
# 139             15
# 179             15
# 254             15
# 258             15
# 263             15
# 381             15
# 387             15
# 420             15

# %% [markdown]
# ### Distribuição

# %%
alunos.distribuicao_pontuacao()

# %% [markdown]
# ### Simulacoes realizadas

# %% [markdown]
# Média de simulações realizadas por turma

# %%
alunos.media_simulacoes_realizadas_por_turma()
# Out:
#      Turma  Num_simulacoes
# 0   10LPNW        1.976923
# 1   10LPNX        1.929134
# 2   10LPNY        2.007299
# 3   10LPNZ        1.950413
# 4    1LPNW        1.976923
# 5    1LPNX        1.990991
# 6    1LPNY        2.046512
# 7    1LPNZ        2.126984
# 8    2LPNW        1.974359
# 9    2LPNX        2.100840
# 10   2LPNY        2.030534
# 11   2LPNZ        2.070312
# 12   3LPNW        2.016949
# 13   3LPNX        2.009091
# 14   3LPNY        2.138889
# 15   3LPNZ        2.073171
# 16   4LPNW        2.035211
# 17   4LPNX        2.048387
# 18   4LPNY        2.025424
# 19   4LPNZ        1.991870
# 20   5LPNW        2.089655
# 21   5LPNX        1.957627
# 22   5LPNY        1.969697
# 23   5LPNZ        1.983193
# 24   6LPNW        2.049180
# 25   6LPNX        1.926829
# 26   6LPNY        1.938356
# 27   6LPNZ        2.087719
# 28   7LPNW        2.094488
# 29   7LPNX        2.074074
# 30   7LPNY        1.908397
# 31   7LPNZ        1.991935
# 32   8LPNW        2.090909
# 33   8LPNX        1.918519
# 34   8LPNY        1.921739
# 35   8LPNZ        1.950413
# 36   9LPNW        1.890625
# 37   9LPNX        2.000000
# 38   9LPNY        2.007937
# 39   9LPNZ        1.878049

# %% [markdown]
# Pontuação média por quantidade de simulações

# %%
alunos.pontuaca_media_por_quantidade_simulacoes()
# Out:
#    Num_simulacoes    Pontuacao
# 0               1   456.318616
# 1               2   918.936302
# 2               3  1378.065651

# %% [markdown]
# ### Insígnias

# %%
alunos.distribuicao_insignias()
# Out:
#     Num_insignias  count
# 0               0    580
# 1               4    545
# 2               1    535
# 3               2    535
# 4               5    523
# 5               3    494
# 6               9    271
# 7               8    258
# 8               6    255
# 9              10    254
# 10              7    224
# 11             15    119
# 12             13    112
# 13             11    108
# 14             14     95
# 15             12     91

# %%
alunos.pontuacao_por_numero_insignias()
# Out:
#     Num_insignias  Pontuacao
# 0               0        0.0
# 1               1      185.0
# 2               2      370.0
# 3               3      555.0
# 4               4      740.0
# 5               5      925.0
# 6               6     1110.0
# 7               7     1295.0
# 8               8     1480.0
# 9               9     1665.0
# 10             10     1850.0
# 11             11     2035.0
# 12             12     2220.0
# 13             13     2405.0
# 14             14     2590.0
# 15             15     2775.0

# %% [markdown]
# ### Desempenho por turma

# %%
alunos.diferenca_desempenho_por_turma()
# Out:
#      Turma    Pontuacao  Num_simulacoes
# 0   10LPNW   930.692308        1.976923
# 1   10LPNX   923.543307        1.929134
# 2   10LPNY   902.043796        2.007299
# 3   10LPNZ   845.495868        1.950413
# 4    1LPNW   946.346154        1.976923
# 5    1LPNX   966.666667        1.990991
# 6    1LPNY   986.666667        2.046512
# 7    1LPNZ   955.833333        2.126984
# 8    2LPNW   910.769231        1.974359
# 9    2LPNX  1005.840336        2.100840
# 10   2LPNY   841.679389        2.030534
# 11   2LPNZ   964.023438        2.070312
# 12   3LPNW   950.084746        2.016949
# 13   3LPNX   923.318182        2.009091
# 14   3LPNY   998.657407        2.138889
# 15   3LPNZ  1012.235772        2.073171
# 16   4LPNW   910.669014        2.035211
# 17   4LPNX   953.346774        2.048387
# 18   4LPNY   866.991525        2.025424
# 19   4LPNZ   967.113821        1.991870
# 20   5LPNW   978.586207        2.089655
# 21   5LPNX  1047.288136        1.957627
# 22   5LPNY   943.219697        1.969697
# 23   5LPNZ   817.731092        1.983193
# 24   6LPNW   917.418033        2.049180
# 25   6LPNX   977.642276        1.926829
# 26   6LPNY   846.438356        1.938356
# 27   6LPNZ   981.798246        2.087719
# 28   7LPNW  1008.031496        2.094488
# 29   7LPNX   957.888889        2.074074
# 30   7LPNY   867.099237        1.908397
# 31   7LPNZ   893.669355        1.991935
# 32   8LPNW   915.189394        2.090909
# 33   8LPNX   870.185185        1.918519
# 34   8LPNY   785.043478        1.921739
# 35   8LPNZ   895.950413        1.950413
# 36   9LPNW   794.921875        1.890625
# 37   9LPNX   848.333333        2.000000
# 38   9LPNY   900.039683        2.007937
# 39   9LPNZ   827.235772        1.878049

# %% [markdown]
# ## Tabela Professores

# %%
professores = funcoes.receber_dados_professores()

# %%
professores.media_idade_sexo()
# Out:
#   Sexo      Idade
# 0    F  47.503597
# 1    M  47.207207

# %%
professores.mediana_idade_sexo()
# Out:
#   Sexo  Idade
# 0    F   48.0
# 1    M   49.0

# %%
professores.media_geral_idade()
# Out:
# Média de idade dos professores: 47.372

# %%
professores.maiores_idades()
# Out:
# As 10 maiores idades dos professores:
#                   Nome  Idade Sexo  Registro
# 12       Tiffany Allen     70    F      7936
# 56        Carla Kelley     70    F      1804
# 98            Lisa Lee     70    F      1576
# 145     Michael Carter     70    M      7431
# 168         Lori Lewis     70    F      1063
# 221  Tiffany Alexander     70    F      3023
# 225      Jessica Salas     70    F      4639
# 227          Amy Kirby     70    F      7864
# 238        Robert Mays     70    M      5067
# 36    Jennifer Fleming     69    F      2981

# %%
professores.distribuicao_idade()

# %% [markdown]
# ## Tabela Coordenadores

# %%
coordenadores = funcoes.receber_dados_coordenadores()

# %%
coordenadores.grafico_sexo_por_idade()

# %% [markdown]
# ## Tabela Turmas

# %%
turmas = funcoes.receber_dados_turmas()

# %% [markdown]
# ### Distribuição por período

# %%
turmas.distribuicao_periodo()

# %% [markdown]
# # Atualização de dados

# %% [markdown]
# ## Professor

# %% [markdown]
# ### Adicionar

# %%
professorNovo = Professor.Professor(Nome='Rogério Carlos',Idade=40,Sexo='M',Registro=8004)
professores.adicionarProfessor(professorNovo)
professores.df.tail()
# Out:
# Professor de registro 8004 adicionado com sucesso.
#                    Nome  Idade Sexo  Registro
# 246       Tanya Gilmore     33    F      9233
# 247  Alejandro Johnston     52    M      5597
# 248      Dawn Fernandez     41    F      9375
# 249        Steven James     56    M      2754
# 250      Rogério Carlos     40    M      8004

# %% [markdown]
# ### Modificar

# %%
professores.modificar_professor_por_registro(Registro=8004,novo_nome='Silvio Ribeiro')
professores.df.tail()
# Out:
# Dados do professor com Registro 8004 modificados com sucesso.
#                    Nome  Idade Sexo  Registro
# 246       Tanya Gilmore     33    F      9233
# 247  Alejandro Johnston     52    M      5597
# 248      Dawn Fernandez     41    F      9375
# 249        Steven James     56    M      2754
# 250      Silvio Ribeiro     40    M      8004

# %% [markdown]
# ### Deletar

# %%
professores.deletar_professor_por_registro(registro=8004)
professores.df.tail()
# Out:
# Professor com Registro 8004 excluído com sucesso.
#                    Nome  Idade Sexo  Registro
# 245       Matthew David     49    M      9929
# 246       Tanya Gilmore     33    F      9233
# 247  Alejandro Johnston     52    M      5597
# 248      Dawn Fernandez     41    F      9375
# 249        Steven James     56    M      2754

# %% [markdown]
# ## Coordenador

# %% [markdown]
# ### Adicionar

# %%
novoCoordenador = Coordenador.Coordenador(Nome='Luma Barbara',Idade=34,Sexo='F',Registro=9348)
coordenadores.adicionarcoordenador(novoCoordenador)
coordenadores.df.tail()
# Out:
# coordenador de registro 9348 adicionado com sucesso.
#               Nome  Idade Sexo  Registro
# 6    Julie Johnson     29    F      2752
# 7    Jacob Hoffman     54    M      6031
# 8   Ashley Webster     54    F      5698
# 9    Daniel Dennis     40    M      1282
# 10    Luma Barbara     34    F      9348

# %% [markdown]
# ### Modificar

# %%
coordenadores.modificar_coordenador_por_registro(Registro=9348,novo_nome='Silvana Almeida')
coordenadores.df.tail()
# Out:
# Dados do coordenador com Registro 9348 modificados com sucesso.
#                Nome  Idade Sexo  Registro
# 6     Julie Johnson     29    F      2752
# 7     Jacob Hoffman     54    M      6031
# 8    Ashley Webster     54    F      5698
# 9     Daniel Dennis     40    M      1282
# 10  Silvana Almeida     34    F      9348

# %% [markdown]
# ### Deletar

# %%
coordenadores.deletar_coordenador_por_registro(registro=9348)
coordenadores.df.tail()
# Out:
# coordenador com Registro 9348 excluído com sucesso.
#              Nome  Idade Sexo  Registro
# 5     John Garcia     49    M      9141
# 6   Julie Johnson     29    F      2752
# 7   Jacob Hoffman     54    M      6031
# 8  Ashley Webster     54    F      5698
# 9   Daniel Dennis     40    M      1282

# %% [markdown]
# ## Turmas

# %% [markdown]
# ### Adicionar

# %%
turma = Turma.Turma(Nome='4LPNY',Periodo='Noturno',Coordenador_responsavel='Gary Le', Professor_responsavel='Timothy Myers')
turmas.adicionarTurma(turma)
turmas.df.tail()
# Out:
# Turma de Nome 4LPNY adicionado com sucesso.
#      Nome   Periodo Coordenador_responsavel Professor_responsavel
# 35  2LPNY   Noturno     Dr. Alicia Castillo         Ethan Mcclure
# 36  8LPNX  Matutino            Joseph Jones        Laura Anderson
# 37  2LPNX  Matutino           Julie Johnson           Frank Payne
# 38  9LPNY  Matutino                John Doe            Jane Smith
# 39  4LPNY   Noturno                 Gary Le         Timothy Myers

# %% [markdown]
# ### Modificar

# %%
turmas.modificar_Turma_por_Nome(Nome='4LPNY',novo_periodo='Matutino')
turmas.df.tail()
# Out:
# Dados do Turma com Nome 4LPNY modificados com sucesso.
#      Nome   Periodo Coordenador_responsavel Professor_responsavel
# 35  2LPNY   Noturno     Dr. Alicia Castillo         Ethan Mcclure
# 36  8LPNX  Matutino            Joseph Jones        Laura Anderson
# 37  2LPNX  Matutino           Julie Johnson           Frank Payne
# 38  9LPNY  Matutino                John Doe            Jane Smith
# 39  4LPNY  Matutino                 Gary Le         Timothy Myers

# %% [markdown]
# ### Deletar

# %%
turmas.deletar_Turma_por_Nome(Nome='4LPNY')
turmas.df.tail()
# Out:
# Turma com Nome 4LPNY excluído com sucesso.
#      Nome   Periodo Coordenador_responsavel     Professor_responsavel
# 34  9LPNW  Matutino           Julie Johnson  Mrs. Katherine Robertson
# 35  2LPNY   Noturno     Dr. Alicia Castillo             Ethan Mcclure
# 36  8LPNX  Matutino            Joseph Jones            Laura Anderson
# 37  2LPNX  Matutino           Julie Johnson               Frank Payne
# 38  9LPNY  Matutino                John Doe                Jane Smith

# %% [markdown]
# ## Alunos

# %% [markdown]
# ### Adicionar

# %%
alunos.add_student('João Silva', 18, 'M', '9LPNX', 235438, 950, 2, 10)
alunos.df.tail()
# Out:
# Aluno com RM 235438 adicionado com sucesso.
#                  Nome  Idade Sexo   Turma      Rm  Pontuacao  Num_simulacoes  \
# 4995       Karen Ryan     46    F   1LPNY  121316        740               2
# 4996   Joseph Kennedy     39    M  10LPNX  336311        555               1
# 4997  Connor Anderson     28    M   1LPNW  338142       1480               2
# 4998    Kurt Sullivan     40    M   5LPNZ  743022       1480               3
# 4999       João Silva     18    M   9LPNX  235438        950               2
#
#       Num_insignias
# 4995              4
# 4996              3
# 4997              8
# 4998              8
# 4999             10

# %% [markdown]
# ### Modificar

# %%
alunos.modify_student_by_rm(235438,"Silva",18)
alunos.df.tail()
# Out:
# Dados do aluno com RM 235438 modificados com sucesso.
#                  Nome  Idade Sexo   Turma      Rm  Pontuacao  Num_simulacoes  \
# 4995       Karen Ryan     46    F   1LPNY  121316        740               2
# 4996   Joseph Kennedy     39    M  10LPNX  336311        555               1
# 4997  Connor Anderson     28    M   1LPNW  338142       1480               2
# 4998    Kurt Sullivan     40    M   5LPNZ  743022       1480               3
# 4999            Silva     18    M   9LPNX  235438        950               2
#
#       Num_insignias
# 4995              4
# 4996              3
# 4997              8
# 4998              8
# 4999             10

# %% [markdown]
# ### Deletar

# %%
alunos.delete_student_by_rm(235438)
alunos.df.tail()
# Out:
# Aluno com RM 235438 excluído com sucesso.
#                  Nome  Idade Sexo   Turma      Rm  Pontuacao  Num_simulacoes  \
# 4994     Robert Allen     32    M  10LPNX  246078       1480               3
# 4995       Karen Ryan     46    F   1LPNY  121316        740               2
# 4996   Joseph Kennedy     39    M  10LPNX  336311        555               1
# 4997  Connor Anderson     28    M   1LPNW  338142       1480               2
# 4998    Kurt Sullivan     40    M   5LPNZ  743022       1480               3
#
#       Num_insignias
# 4994              8
# 4995              4
# 4996              3
# 4997              8
# 4998              8

# %% [markdown]
# # Solucão para análise de desempenho

# %%
aluno = Aluno.Aluno(Nome='Carlos Notorio',Idade=19,Sexo='M',Turma='TurmaX',Rm=116743,Pontuacao=2600,Num_simulacoes=3,Num_insignias=11)
alunos.analiseAluno(aluno)
# Out:
# Parabéns, você teve uma pontuação maior do que o previsto.
# Pontuação prevista de 2035.0, sua pontuacao foi de 2600

# %%
aluno = Aluno.Aluno(Nome='Carlos Notorio',Idade=19,Sexo='M',Turma='TurmaX',Rm=116743,Pontuacao=160,Num_simulacoes=1,Num_insignias=1)
alunos.analiseAluno(aluno)
# Out:
# Você não obteve uma pontuação maior do que o previsto, continue treinando!
# Pontuação prevista de 185.0, sua pontuacao foi de 160
